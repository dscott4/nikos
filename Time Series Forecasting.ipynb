# %%
import numpy as np
print('Numpy: {}'.format(np.__version__))
import pandas
print('Pandas: {}'.format(pandas.__version__))
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Numpy: 1.11.3
# Pandas: 0.19.2

# %%
# load dataset
df = pandas.read_csv("preprocessing/kept_variables.csv", header=None)
#df.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
print(df.head(5))
dataset = df.values
    
#[float(i) for i in dataset]
m, n = dataset.shape
# split into input (X) and output (Y) variables
X = dataset[1:round(2*m/3),1:(n-1)]
Y = dataset[1:round(2*m/3),(n-1)]
# Out:
#           0        1         2         3         4         5        6  \
# 0 -1.711065  1.49574 -1.696300  0.429632 -0.133907  0.743256 -0.62275
# 1 -1.711065  1.49574 -1.624112  0.429632 -0.133907  0.743256 -0.62275
# 2 -1.711065  1.49574 -1.551925  0.274033 -0.133907  0.231636 -0.62275
# 3 -1.711065  1.49574 -1.479737  0.248101 -0.133907  0.231636 -0.62275
# 4 -1.711065  1.49574 -1.407549  0.222167 -0.133907  0.231636 -0.62275
#
#           7         8
# 0 -1.536252  0.171546
# 1 -1.536252 -0.225537
# 2 -0.681351 -0.316169
# 3 -1.108801 -0.555942
# 4 -1.536252 -0.750611

# %%
from pandas import read_csv

# load dataset
# specify columns to plot
groups = [3, 4, 5, 6, 7, 8]
i = 1
# plot each column
pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(dataset[:, group])
    #pyplot.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
pyplot.show()

# %%
scatter(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-213fa8031d31> in <module>()
# ----> 1 scatter(dataset)
#
# NameError: name 'scatter' is not defined
